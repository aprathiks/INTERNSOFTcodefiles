# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot(np.random.normal(size=200), np.random.normal(size=200), 'o')

# %%
print(np.random.normal(size=200))
# Out:
# [ 6.07037115e-02  9.54153533e-01 -6.79140127e-01  2.10221408e+00
#  -1.06460033e+00  1.15900202e+00  2.84404898e-01  9.69536920e-01
#  -1.41300522e+00  2.65919547e+00  8.82469298e-01  1.35199572e-01
#   1.05898216e+00 -1.34282322e-01  1.70834543e+00 -9.79958610e-01
#   1.15355662e+00 -1.66119397e+00 -5.56108340e-01 -1.24593137e-01
#  -1.10169574e+00 -1.60034097e+00 -3.07771285e-01 -5.02769320e-01
#  -5.10317425e-01  1.35825015e+00  1.00334535e+00 -1.49533719e+00
#   4.24171546e-02 -1.36935619e+00  3.76167254e-01  1.73087610e+00
#   1.54643538e+00  1.54902386e+00  9.59618341e-02  1.30944898e+00
#   1.24479738e+00 -2.32372037e+00  3.15190303e-02 -7.14261992e-01
#  -4.79495885e-01  6.52571680e-02  2.36713974e-01 -7.17651807e-01
#  -8.54396065e-01 -1.55103816e+00  1.04012326e+00 -2.24517805e+00
#  -1.55610294e-01  1.04299328e+00 -1.17048122e+00  1.45409991e+00
#   4.29208639e-01  1.98965421e+00 -7.33290969e-01 -1.03622961e+00
#  -8.85592424e-01  6.48048500e-01  5.16268912e-01 -8.07063893e-02
#  -1.08094945e-01 -5.38031680e-01  2.19229227e-01 -1.29538973e-01
#  -2.47916404e-01  2.27722511e-01 -4.27651899e-01  6.74898055e-01
#  -9.33778394e-01 -6.97947267e-01 -4.34084149e-02 -3.00483032e-02
#   2.29573424e-01  2.69636342e-01  1.71506780e+00  1.82399009e+00
#   2.39103084e-01  9.36368769e-01  6.33695536e-02  6.65503028e-01
#   4.56086407e-01 -1.34981569e+00 -4.12415865e-01 -3.92006381e-01
#   5.71338082e-01  5.39041453e-01 -1.72521278e+00 -9.87645463e-01
#  -3.96718942e-01  2.36240240e+00  1.58113468e+00 -1.32737796e+00
#  -3.08928691e-01  2.09639299e-01  1.00137157e+00 -3.37469928e+00
#  -7.42192150e-01 -6.61100373e-01 -4.03517523e-02 -1.67551314e+00
#  -8.17842730e-01  5.52789439e-01 -7.97659337e-01 -2.08390985e+00
#   3.38618058e-03 -7.33295580e-02 -4.57627740e-01 -6.52905535e-01
#   9.37156193e-01  9.25422159e-01  1.04313328e+00 -4.16689553e-01
#   1.62328245e+00 -2.28736917e-01 -3.04305091e-01  9.00953182e-01
#  -8.97180659e-01  5.70684630e-01 -2.63756384e-01 -9.92062109e-01
#   5.50710955e-02 -3.23137883e-01 -1.04261991e+00  9.74140706e-01
#   8.05910758e-01  4.49708547e-01 -2.04792096e-01  2.52151712e+00
#  -5.15199998e-01 -1.38040543e+00  6.73723133e-01 -8.53820682e-01
#  -7.61793840e-02  1.05266174e+00 -1.83114126e-01  6.86627119e-01
#   4.54891856e-01 -5.87652429e-01  4.85919726e-01 -7.86029401e-01
#   1.72431672e-01 -5.40012016e-01  6.62888684e-01 -5.28089262e-01
#   1.17743248e+00  1.02195890e+00 -6.12969841e-02  9.25555703e-01
#  -4.80876249e-02 -8.89244184e-01  1.44324102e+00 -2.17063763e+00
#   5.19864651e-01 -9.65918231e-01  1.78416660e+00 -1.89976834e+00
#  -4.57077645e-01  4.24436657e-01 -8.33408416e-01  2.33211785e+00
#   4.58895114e-01 -1.30866367e+00 -2.24423315e+00  4.45214852e-01
#   9.90167919e-01 -1.23542416e+00  1.44030048e-01 -1.15047592e+00
#   3.94365778e-02  1.04227990e+00  1.09057539e+00 -5.27344083e-01
#   5.69668435e-01 -1.96558183e-01 -5.90559865e-01 -1.71646799e+00
#   3.34106936e-01 -1.80710056e-01  2.25122399e-01 -2.60636004e+00
#   2.59821729e-01  1.12675548e+00  3.00890935e-01 -1.74478224e-03
#  -1.63371789e-01 -6.84676640e-01  4.97613005e-01  8.92477078e-02
#  -5.50171467e-02  2.12970760e+00  3.95730480e-01  2.18090650e+00
#  -7.61900686e-01 -6.45292387e-01  1.95765823e-01 -1.22606874e+00
#  -3.28645182e-01 -9.16514397e-01  6.78361448e-01 -4.29354897e-02]

# %%
print(np.random.normal(size=10))
# Out:
# [ 0.85441626  1.14515688 -0.12307936  0.15113796  0.16286121 -1.73349549
#  -0.19018722 -1.90021662 -0.45957304 -1.14561166]

# %%
# %matplotlib inline

# %%
plt.plot(np.random.normal(size=200), np.random.normal(size=200), 'd')

# %%
plt.plot(np.random.normal(size=200), np.random.normal(size=200), 'c')

# %%
plt.plot(np.random.normal(size=200), np.random.normal(size=200), 'p')

# %%
plt.plot(np.random.normal(size=10), np.random.normal(size=10), 'p')

# %%
print(np.random.normal(size=10))
# Out:
# [ 2.36825989  1.09147077  1.25409334  0.50247903  0.15133781  0.55915012
#  -0.37685871 -0.91212342 -0.29821465 -0.75779238]

# %%
print(np.random.normal(size=10))
# Out:
# [-1.85018874 -0.86492831  0.15569901 -0.66538269 -0.08979803 -0.86858912
#  -0.37277053 -0.89701644  0.09009738 -1.27734076]

# %%
plt.plot(np.random.normal(size=10), np.random.normal(size=10), 'p')

# %%
print(np.random.normal(size=10), np.random.normal(size=10))
# Out:
# [-1.63417444 -0.72995215 -1.88903997 -1.29611421  1.4196337  -0.22027188
#   2.01571852  0.28015825 -0.66572474  1.32182924] [-1.56807318  1.13003387  0.23043432 -1.52536603 -0.55186944  0.4869247
#   0.6505928   0.88387206 -0.94505898  0.68899499]

# %%
normals=pd.Series(np.random.normal(size=30))
normals.plot()

# %%
no=pd.Series(np.random.normal(size=50))
no.plot()

# %%
normals=pd.Series(np.random.normal(size=30))
print(normals)
normals.plot()
# Out:
# 0     0.038433
# 1     0.472292
# 2    -1.033299
# 3    -2.085606
# 4    -0.290255
# 5     0.359171
# 6     0.825966
# 7     0.314103
# 8    -1.540795
# 9     0.845215
# 10    0.579310
# 11   -0.334653
# 12   -0.038073
# 13   -1.137422
# 14    0.403246
# 15    0.925015
# 16    0.270514
# 17    0.486962
# 18    0.614841
# 19    0.150401
# 20    0.156625
# 21    1.752538
# 22   -1.332027
# 23   -2.160212
# 24   -1.441191
# 25   -0.855567
# 26    0.052037
# 27    0.575040
# 28   -0.283078
# 29    1.017450
# dtype: float64

# %%
normals=pd.Series(np.random.normal(size=30))
print(normals)
normals.plot()
# Out:
# 0    -0.583270
# 1    -0.951692
# 2     1.048732
# 3    -1.525519
# 4    -1.322362
# 5    -0.899057
# 6     1.066616
# 7    -0.337429
# 8    -0.308104
# 9     0.938995
# 10    0.001041
# 11    0.416851
# 12   -1.265551
# 13    0.963560
# 14    0.528859
# 15    1.108790
# 16   -1.009967
# 17   -1.913978
# 18   -0.558777
# 19   -1.642004
# 20   -1.949358
# 21   -0.694233
# 22   -0.393853
# 23   -0.196059
# 24    0.340072
# 25   -0.805340
# 26    0.061750
# 27   -0.381389
# 28    1.635262
# 29   -1.004907
# dtype: float64

# %%
normals.cumsum().plot(grid=True)

# %%
no.cumsum().plot(grid=True)

# %%
no.cumsum().plot(grid=False)

# %%
variables = pd.DataFrame({'normal': np.random.normal(size=10), 
                       'gamma': np.random.gamma(1, size=10), 
                       'poisson': np.random.poisson(size=10)})
print(variables)

variables.cumsum(0).plot()
# Out:
#      normal     gamma  poisson
# 0  1.303520  1.902634        2
# 1  0.887598  2.363525        1
# 2  0.527200  0.083549        1
# 3  0.037898  0.493777        2
# 4 -0.202231  0.088507        1
# 5  1.651448  1.474757        0
# 6 -1.491802  0.011440        0
# 7 -0.949407  0.176788        1
# 8  0.450715  0.244268        0
# 9 -0.572112  0.171931        1

# %%
variables = pd.DataFrame({'normal': np.random.normal(size=10), 
                       'gamma': np.random.gamma(1, size=10), 
                       'poisson': np.random.poisson(size=10)})
print(variables)

variables.cumsum(1).plot()
# Out:
#      normal     gamma  poisson
# 0 -0.774181  0.775653        1
# 1  0.465287  0.029234        1
# 2  0.195143  0.878465        1
# 3  0.135281  1.246691        1
# 4  0.410224  0.339847        1
# 5 -0.849512  0.396358        0
# 6 -0.476104  2.030695        1
# 7  0.925175  2.712106        0
# 8 -1.296068  0.181713        2
# 9 -0.066635  0.016463        3

# %%
variables = pd.DataFrame({'normal': np.random.normal(size=10), 
                       'gamma': np.random.gamma(1, size=10), 
                       'poisson': np.random.poisson(size=10)})
print(variables)

variables.cumsum(1).plot()
# Out:
#      normal     gamma  poisson
# 0  0.324150  0.117818        2
# 1 -0.613858  0.273622        2
# 2  0.744991  0.485085        0
# 3  0.270800  0.296602        1
# 4 -0.264951  0.589924        0
# 5 -0.163027  1.095348        0
# 6 -0.431428  0.931754        2
# 7  1.125606  0.636655        0
# 8 -1.719213  0.137208        0
# 9  0.477022  0.074073        1

# %%
variables = pd.DataFrame({'School': np.random.normal(size=10), 
                       'College': np.random.gamma(1, size=10), 
                       'Home': np.random.poisson(size=10)})
print(variables)

variables.cumsum(0).plot()
# Out:
#      School   College  Home
# 0 -0.187581  0.988410     1
# 1 -0.244864  0.416574     0
# 2 -0.477162  0.591042     2
# 3  0.760209  0.039075     0
# 4  0.214512  0.467178     3
# 5  0.590544  0.139326     2
# 6  0.810663  2.431815     2
# 7  1.458501  1.171697     1
# 8 -1.277526  0.435114     2
# 9 -1.922471  0.079784     1

# %%
variables.cumsum(0).plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017D88E6B0A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017D88EC4610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017D88F5B2B0>],
#       dtype=object)

# %%
variables.cumsum(0).plot()

# %%
variables.cumsum(0).plot(secondary_y='normal')

# %%
variables = pd.DataFrame({'normal': np.random.normal(size=10), 
                       'gamma': np.random.gamma(1, size=10), 
                       'poisson': np.random.poisson(size=10)})
print(variables)

variables.cumsum(1).plot()
# Out:
#      normal     gamma  poisson
# 0 -0.848047  3.517150        0
# 1  0.341900  1.514687        0
# 2 -0.242560  0.386422        0
# 3 -1.203750  0.077412        1
# 4  1.299736  0.322523        2
# 5  0.016565  0.293031        3
# 6 -0.413679  0.835325        3
# 7  1.154611  0.677607        1
# 8  0.021174  0.056036        2
# 9  0.099192  0.960538        0

# %%
variables.cumsum(0).plot(secondary_y='normal')

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(4, 12))
for i,var in enumerate(['normal','gamma','poisson']):
    variables[var].cumsum(0).plot(ax=axes[i], title=var)
axes[0].set_ylabel('cumulative sum')
# Out:
# Text(0, 0.5, 'cumulative sum')

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(6,15))
for i,var in enumerate(['normal','gamma','poisson']):
    variables[var].cumsum(0).plot(ax=axes[i], title=var)
axes[0].set_ylabel('cumulative sum')
# Out:
# Text(0, 0.5, 'cumulative sum')

# %%
fig.savefig('figure.png')

# %%
from IPython.display import Image
Image('figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig = plt.figure()
ax = plt.axes()
s = np.linspace(0, 20, 100)
print(s)
ax.plot(s, np.sin(s));
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
#  15.75757576 15.95959596 16.16161616 16.36363636 16.56565657 16.76767677
#  16.96969697 17.17171717 17.37373737 17.57575758 17.77777778 17.97979798
#  18.18181818 18.38383838 18.58585859 18.78787879 18.98989899 19.19191919
#  19.39393939 19.5959596  19.7979798  20.        ]

# %%
plt.plot(s, np.sin(s))

# %%
plt.plot(np.sin(s), s)

# %%
plt.plot(s, s)

# %%
plt.plot(s, np.tan(s))

# %%
pas = plt.figure()
asp= plt.axes()
s = np.linspace(50, 100, 100)
print(s)
asp.plot(s, s);
# Out:
# [ 50.          50.50505051  51.01010101  51.51515152  52.02020202
#   52.52525253  53.03030303  53.53535354  54.04040404  54.54545455
#   55.05050505  55.55555556  56.06060606  56.56565657  57.07070707
#   57.57575758  58.08080808  58.58585859  59.09090909  59.5959596
#   60.1010101   60.60606061  61.11111111  61.61616162  62.12121212
#   62.62626263  63.13131313  63.63636364  64.14141414  64.64646465
#   65.15151515  65.65656566  66.16161616  66.66666667  67.17171717
#   67.67676768  68.18181818  68.68686869  69.19191919  69.6969697
#   70.2020202   70.70707071  71.21212121  71.71717172  72.22222222
#   72.72727273  73.23232323  73.73737374  74.24242424  74.74747475
#   75.25252525  75.75757576  76.26262626  76.76767677  77.27272727
#   77.77777778  78.28282828  78.78787879  79.29292929  79.7979798
#   80.3030303   80.80808081  81.31313131  81.81818182  82.32323232
#   82.82828283  83.33333333  83.83838384  84.34343434  84.84848485
#   85.35353535  85.85858586  86.36363636  86.86868687  87.37373737
#   87.87878788  88.38383838  88.88888889  89.39393939  89.8989899
#   90.4040404   90.90909091  91.41414141  91.91919192  92.42424242
#   92.92929293  93.43434343  93.93939394  94.44444444  94.94949495
#   95.45454545  95.95959596  96.46464646  96.96969697  97.47474747
#   97.97979798  98.48484848  98.98989899  99.49494949 100.        ]

# %%
plt.plot(s, np.sin(s));

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 1), color='y')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='blue')        
plt.plot(s, np.sin(s - 1), color='y')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 1), color='0.55')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 1), color='b')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 0), color='y')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 1), color='y')           
plt.plot(s, np.sin(s - 1), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), color='red')        
plt.plot(s, np.sin(s - 1), color='y')           
plt.plot(s, np.sin(s - 2), color='0.55')

# %%
plt.plot(s, np.sin(s - 0), linestyle='-')        
plt.plot(s, np.sin(s - 1), linestyle=':')           
plt.plot(s, np.sin(s - 2), linestyle='-.')

# %%
plt.plot(s, np.sin(s - 0), linestyle='-')        
plt.plot(s, np.sin(s - 1), linestyle=':')           
plt.plot(s, np.sin(s - 2), linestyle=':')

# %%
plt.plot(s, np.sin(s - 0), linestyle='-')        
plt.plot(s, np.sin(s - 1), linestyle=':')           
plt.plot(s, np.sin(s - 1), linestyle=':')

# %%
s = np.linspace(0, 20, 100)
print(s)
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
#  15.75757576 15.95959596 16.16161616 16.36363636 16.56565657 16.76767677
#  16.96969697 17.17171717 17.37373737 17.57575758 17.77777778 17.97979798
#  18.18181818 18.38383838 18.58585859 18.78787879 18.98989899 19.19191919
#  19.39393939 19.5959596  19.7979798  20.        ]

# %%
plt.plot(s, np.sin(s - 0))

plt.xlim(-1, 15)
plt.ylim(-2, 2);

# %%
plt.plot(s, np.sin(s - 0))

plt.xlim(-1, 20)
plt.ylim(-2, 3);

# %%
s = np.linspace(50, 100, 100)

# %%
plt.plot(s, np.cos(s))
plt.title("Cosine Curve")
plt.xlabel("x")
plt.ylabel("cos(x)")
# Out:
# Text(0, 0.5, 'cos(x)')

# %%
plt.plot(s, np.cos(s))
plt.title("My graph")
plt.xlabel("x")
plt.ylabel("cos(x)")
# Out:
# Text(0, 0.5, 'cos(x)')

# %%
plt.plot(s, np.cos(s))
plt.title("My graph")
plt.xlabel("my(y)")
plt.ylabel("x")
# Out:
# Text(0, 0.5, 'x')

# %%
plt.plot(s, np.cos(s))
plt.title("My graph")
plt.xlabel("my(x)")
plt.ylabel("my(y)")
# Out:
# Text(0, 0.5, 'my(y)')

# %%
plt.style.use('seaborn-whitegrid')

# %%
x = np.linspace(1, 10, 50)
y = np.log(x)

plt.plot(x, y, 'o-', color='green')

# %%
x = np.linspace(70, 100, 50)
y = np.log(x)

plt.plot(x, y, 'o-', color='y')

# %%
x = np.linspace(1, 10, 50)
y = np.sin(x)

plt.plot(x, y, 'o-', color='green')

# %%
plt.plot(x, y, '-or');

# %%
plt.plot(x, y, '-oy');

# %%
plt.plot(x, y, '-ob');

# %%
plt.plot(x, y, '-og');

# %%
plt.scatter(x, y, marker='o')

# %%
plt.scatter(x, y, marker='o');

# %%
plt.scatter(x, y, marker='p')

# %%
plt.scatter(x, y, marker='d')

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(7)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5,
            cmap='Reds')
plt.colorbar()

# %%
x = np.linspace(0, 10, 100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x, y, yerr=dy, fmt='.b');

# %%
x = np.linspace(0, 10, 100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x, y, yerr=dy, fmt='.r');

# %%
x = np.linspace(50, 100, 100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x, y, yerr=dy, fmt='.b');

# %%
x = np.linspace(0, 10, 100)
dy = 0.5
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x, y, yerr=dy, fmt='.b');

# %%
x = np.linspace(0, 10, 100)
dy = 0.1
y = np.sin(x) + dy * np.random.randn(100)

plt.errorbar(x, y, xerr=dy, fmt='.b');

# %%
plt.style.use('seaborn-white')
data = np.random.randn(10000)

# %%
print(data)
# Out:
# [ 1.02572495  0.96325024  0.53361558 ...  0.05480693 -1.56337612
#  -0.14421986]

# %%
plt.hist(data)
# Out:
# (array([   6.,   46.,  326., 1311., 2621., 2974., 1855.,  709.,  140.,
#           12.]),
#  array([-4.05674256, -3.2837866 , -2.51083065, -1.7378747 , -0.96491875,
#         -0.19196279,  0.58099316,  1.35394911,  2.12690507,  2.89986102,
#          3.67281697]),
#  <a list of 10 Patch objects>)

# %%
plt.style.use('seaborn-white')
data2 = np.random.randn(100)

# %%
print(data2)
# Out:
# [-4.65374866e-01  2.00526448e-01  1.46596553e+00 -3.76156649e-01
#  -2.28151420e+00 -7.73551710e-01 -7.40923621e-01 -2.95862396e-01
#   2.66052563e-01  2.90095833e-01 -5.64805098e-01  2.41205575e-01
#   1.12973963e+00  9.76073789e-02  1.05050388e+00 -2.88883167e-01
#  -1.89472267e+00 -2.16604832e-01 -1.69601142e+00 -1.08649993e+00
#   6.44377511e-01 -9.43256204e-01  4.90651219e-03 -2.85672133e-02
#   7.29971704e-01 -7.67360240e-01  1.06313145e+00 -5.36434349e-01
#   8.86643441e-01  1.36543763e+00  1.33696998e+00  1.35320895e+00
#   1.47307983e+00 -7.24881915e-01  2.71937979e+00 -6.24533581e-01
#  -3.48092409e-01 -7.19320585e-01  3.19771353e-01 -1.90196781e-01
#   3.16941339e-01  1.05434503e+00 -8.94822005e-01  1.89615066e+00
#   2.30669207e-01  8.35047241e-01 -1.61098135e+00  1.51017987e-01
#  -6.06479556e-01  5.03440544e-01 -4.01575792e-01  1.14376057e+00
#   1.65859016e-01  1.75778726e-02 -2.54483966e-02 -6.10924549e-01
#   8.99806257e-01 -1.91058421e-01  1.29932693e+00  2.77590433e-01
#   1.08173092e+00  2.19488764e-03  1.19442723e+00 -1.77871194e+00
#  -2.16961413e-01 -5.91778070e-01 -1.47102132e+00 -2.15148382e-01
#  -4.31820847e-01 -7.61735666e-01 -1.46138015e+00 -5.27492633e-01
#   1.08937390e-01  5.81272564e-01  2.18862350e-01  7.65569645e-01
#   9.18928916e-01  1.76428855e+00 -1.62094715e+00  9.36100542e-01
#   4.58706225e-01 -7.73696656e-01 -1.27251884e-01 -6.55155965e-01
#   4.56826510e-01 -2.33572229e-01 -2.15863017e+00 -2.58475220e-01
#  -8.71013554e-01  4.39106502e-01 -1.45318692e+00  1.35345594e+00
#  -2.04016202e+00  1.38368109e+00  6.52467254e-01 -1.80234365e+00
#   1.09700591e+00  8.51437081e-01 -4.22733685e-01 -2.62765539e-01]

# %%
plt.hist(data2)
# Out:
# (array([ 5.,  7.,  4., 23., 20., 14., 16.,  8.,  2.,  1.]),
#  array([-2.2815142 , -1.7814248 , -1.2813354 , -0.781246  , -0.2811566 ,
#          0.21893279,  0.71902219,  1.21911159,  1.71920099,  2.21929039,
#          2.71937979]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data2, color='red')
# Out:
# (array([ 5.,  7.,  4., 23., 20., 14., 16.,  8.,  2.,  1.]),
#  array([-2.2815142 , -1.7814248 , -1.2813354 , -0.781246  , -0.2811566 ,
#          0.21893279,  0.71902219,  1.21911159,  1.71920099,  2.21929039,
#          2.71937979]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=30, normed=True, alpha=0.6,
         histtype='stepfilled')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-e144789c9109> in <module>
# ----> 1 plt.hist(data, bins=30, normed=True, alpha=0.6,
#       2          histtype='stepfilled')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
plt.hist(data, bins=5, normed=True, alpha=0.6,
         histtype='stepfilled')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-86eac47a0e1d> in <module>
# ----> 1 plt.hist(data, bins=5, normed=True, alpha=0.6,
#       2          histtype='stepfilled')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
x = np.random.normal(0, 0.8, 1000)
y = np.random.normal(-2, 1, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.5, normed=True, bins=50)

plt.hist(x, **kwargs)
plt.hist(y, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-3b5da5cf6abb> in <module>
#       4 kwargs = dict(histtype='stepfilled', alpha=0.5, normed=True, bins=50)
#       5
# ----> 6 plt.hist(x, **kwargs)
#       7 plt.hist(y, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Polygon' object has no property 'normed'

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [  52 1637 5595 2564  152]

# %%
mean = [5, 2]
cov = [[3, 1], [2, 0.5]]
x, y = np.random.multivariate_normal(mean, cov, 1000)
# Out:
# <ipython-input-92-42815d6f6074>:3: RuntimeWarning: covariance is not positive-semidefinite.
#   x, y = np.random.multivariate_normal(mean, cov, 1000)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-42815d6f6074> in <module>
#       1 mean = [5, 2]
#       2 cov = [[3, 1], [2, 0.5]]
# ----> 3 x, y = np.random.multivariate_normal(mean, cov, 1000)
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.hist2d(x, y, bins=20, cmap='Reds')
cb = plt.colorbar()

# %%
mean = [5, 2]
cov = [[3, 1], [2, 0.5]]
x, y = np.random.multivariate_normal(mean, cov, 10000)
# Out:
# <ipython-input-96-a996c6d7367d>:3: RuntimeWarning: covariance is not positive-semidefinite.
#   x, y = np.random.multivariate_normal(mean, cov, 10000)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-a996c6d7367d> in <module>
#       1 mean = [5, 2]
#       2 cov = [[3, 1], [2, 0.5]]
# ----> 3 x, y = np.random.multivariate_normal(mean, cov, 10000)
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.hist2d(x, y, bins=20, cmap='Reds')
cb = plt.colorbar()

# %%
plt.hexbin(x, y, gridsize=20, cmap='Reds')

cb = plt.colorbar()

# %%
plt.hist(data,bins=30, normed=True, alpha=0.6,
        histtype='stepfilled');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-24d60430bd33> in <module>
# ----> 1 plt.hist(data,bins=30, normed=True, alpha=0.6,
#       2         histtype='stepfilled');
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2603         orientation='vertical', rwidth=None, log=False, color=None,
#    2604         label=None, stacked=False, *, data=None, **kwargs):
# -> 2605     return gca().hist(
#    2606         x, bins=bins, range=range, density=density, weights=weights,
#    2607         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6817             if patch:
#    6818                 p = patch[0]
# -> 6819                 p.update(kwargs)
#    6820                 if lbl is not None:
#    6821                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Polygon' object has no property 'normed'
